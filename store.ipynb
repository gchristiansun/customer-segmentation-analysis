# %% [markdown]
# ### Read and Store Data to Supabase

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv("data/superstore.csv", encoding="ISO-8859-1")

# %%
URL = ""

engine = create_engine(URL)
df.to_sql('orders', engine)
# Out:
# 994
